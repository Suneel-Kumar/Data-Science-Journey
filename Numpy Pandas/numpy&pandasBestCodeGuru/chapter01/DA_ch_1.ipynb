# %% [markdown]
# ## What is Data Analysis?
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-01-25 at 6.42.43 AM.jpeg](data:image/jpeg;base64,...)

# %%
#Chapter-1: Data Manipulation with pandas

# topic 1.1

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#Inspecting a DataFrame
data = pd.read_csv('Data2.csv')

# Print the head of the Data1
# print(data.head(5))
# print(data.tail(6))

# Print information about Data1
# data.info()

# Print the shape of Data1
# print(data.shape)

# Print a description of Data1
# print(data.describe())

# %%
## Import pandas using the alias pd

# Print the values of Data1
# print(data)
# print(data.values)

# Print the column index of Data1
# print(data.columns)

# Print the row index of Data1
# print(data.index)

# %%
# Sort data by individuals
# data_ind = data.sort_values("cpc", ascending=True)

#for two values, we have to use list []

# Print the top few rows
# print(data_ind)

# %%
# data['cpc']
# data.sort_values('cpc', ascending=True)

# %%
#Subsetting columns
 
# Select the cpc and drive_right columns
# data_com = data[['cpc', 'drive_right']]
# Print the head of the result
# print(data_com.head(3))

# %%
# Filter for rows where cpc is greater than 40
# data_gt_40 = data[data["cpc"] < 40]
# print(data["cpc"] < 40)
# See the result
# print(data_gt_40)

# %%
# Filter for rows where Purchased is No
# mountain_reg = data[data['Purchased']=='Yes']

# See the result
# print(mountain_reg)

# %%
# Add total col as sum of individuals and family_members
# data['total'] = data['Country'] + data['Purchased']

# See the result
# print(data.head())

# %%
#Chapter-1: Data Manipulation with pandas

# topic 1.2

# %%
import pandas as pd
# data = pd.read_csv('Data2.csv')

# Print the head of the Data1

# Print the mean of weekly_sales
# print(data['cpc'].mean())

# Print the median of weekly_sales
# print(data.sort_values('cpc', ascending=True))
# print(data['cpc'].median())

# print(data['cpc'].mode())

# print(pd.DataFrame([2,5,6,8,3,2,2]).median())

# print(pd.DataFrame([2,5,6,8,3,2,2]).sort_values(0, ascending=True))

# %%
# Print the maximum of the date column
# print(data)
# print(data['cpc'].max())

# Print the minimum of the date column
# print(data['cpc'].min())

# %%
# Similarly The .agg() method allows you to apply your own custom functions to a DataFrame, 
#as well as apply functions to more than one column of a DataFrame at once, 
#making your aggregations super-efficient.

# %%
#cumulative sum and cumulative max 
#total sum of data as it grows with time

# %%
# print(data)
# print(data['cpc'].cummax())

# %%
# Drop duplicate cpc/purchas combinations
# cpc_purchase = data.drop_duplicates(['Country','drive_right'])
# print(cpc_purchase)

# %%
# Count the number of each type
data1=data.head()
# print(data1)
# cpc_counts = data1['Country'].value_counts()
# print(cpc_counts)

# Get the proportion of stores of each type
# store_props = data1['Country'].value_counts(normalize=True)
# print(store_props)

# Count the number of each department number and sort
# dept_counts_sorted = data['Country'].value_counts(ascending=True,sort=True)
# print(dept_counts_sorted)

# Get the proportion of departments of each number and sort
dept_props_sorted = data1['cpc'].value_counts(sort=True, normalize=True)
print(dept_props_sorted)
# Out:
# 30    0.2
# 40    0.2
# 44    0.2
# 27    0.2
# 38    0.2
# Name: cpc, dtype: float64

# %%
# Calc total cpc
cpc_all = data["cpc"].sum()
cpc_all
# Out:
# 381

# %%
# Group by type; calc total weekly sales
data_by_country = data1.groupby("Country")["cpc"].sum()
data_by_country
# Out:
# Country
# France     44
# Germany    70
# Spain      65
# Name: cpc, dtype: int64

# %%
# Import NumPy with the alias np
import numpy as np

# For each country, aggregate cpc: get min, max, mean, and median
# data_by_country = data.groupby('Country')['cpc'].agg([np.min, np.max, np.mean, np.median])

# Print data_stats
# print(data_by_country)

# For each country, aggregate cpc and purchased: get min, max, mean, and median
unemp_fuel_stats = data.groupby('Country')[['cpc', 'pop']].agg([np.min, np.max, np.mean, np.median])

# Print unemp_fuel_stats
print(unemp_fuel_stats)
# Out:
#           cpc                     pop
#          amin amax  mean median  amin  amax  mean median
# Country
# America    45   45  45.0   45.0  40.0  40.0  40.0   40.0
# Canada     12   12  12.0   12.0   NaN   NaN   NaN    NaN
# China      52   52  52.0   52.0  80.0  80.0  80.0   80.0
# France     35   44  39.5   39.5  10.0  10.0  10.0   10.0
# Germany    30   40  35.0   35.0  30.0  30.0  30.0   30.0
# India      48   48  48.0   48.0  60.0  60.0  60.0   60.0
# Pakistan   10   10  10.0   10.0   NaN   NaN   NaN    NaN
# Spain      27   38  32.5   32.5  20.0  20.0  20.0   20.0

# %%
# Pivot for mean cpc for each country
mean_cpc_by_country = data.pivot_table(values="cpc", index="Country")

# Print mean_cpc for each country
print(mean_cpc_by_country)
# Out:
#            cpc
# Country
# America   45.0
# Canada    12.0
# China     52.0
# France    39.5
# Germany   35.0
# India     48.0
# Pakistan  10.0
# Spain     32.5

# %%
# Print mean cpc by country type; fill missing values with 0
print(data.pivot_table(values='cpc', index='Country', columns='Purchased', fill_value=0))
# Out:
# Purchased  No  Yes
# Country
# America    45    0
# Canada      0   12
# China      52    0
# France     44   35
# Germany    30   40
# India       0   48
# Pakistan    0   10
# Spain      38   27

# %%
print(data.pivot_table(values='cpc', index='Country', columns='Purchased',aggfunc = "count", fill_value=0))
# Out:
# Purchased  No  Yes
# Country
# America     1    0
# Canada      0    1
# China       1    0
# France      1    1
# Germany     1    1
# India       0    1
# Pakistan    0    1
# Spain       1    1

# %%
#Chapter-1: Data Manipulation with pandas

# topic 1.3 Slicing and Indexing

# %%
# print(data)

# %%
# Look at data
# print(data)

# Index data by country
data_ind = data.set_index('Country')

# Look at data_ind
# print(data_ind)

# Reset the index, keeping its contents
print(data_ind.reset_index())

# Reset the index, dropping its contents
print(data_ind.reset_index(drop=True))
# Out:
#      Country  cpc  drive_right Purchased   pop
# 0     France   44         True        No  10.0
# 1      Spain   27        False       Yes  20.0
# 2    Germany   30         True        No  30.0
# 3      Spain   38        False        No  20.0
# 4    Germany   40         True       Yes  30.0
# 5     France   35        False       Yes  10.0
# 6      China   52         True        No  80.0
# 7      India   48         True       Yes  60.0
# 8    America   45         True        No  40.0
# 9     Canada   12        False       Yes   NaN
# 10  Pakistan   10         True       Yes   NaN
#     cpc  drive_right Purchased   pop
# 0    44         True        No  10.0
# 1    27        False       Yes  20.0
# 2    30         True        No  30.0
# 3    38        False        No  20.0
# 4    40         True       Yes  30.0
# 5    35        False       Yes  10.0
# 6    52         True        No  80.0
# 7    48         True       Yes  60.0
# 8    45         True        No  40.0
# 9    12        False       Yes   NaN
# 10   10         True       Yes   NaN

# %%
# Make a list of countries to subset on
countries = ['Pakistan', 'Canada']
# Subset data using square brackets
# print(data[data['Country'].isin(countries)])

# Subset data_ind using .loc[]
print(data_ind.loc[countries])
# Out:
#           cpc  drive_right Purchased  pop
# Country
# Pakistan   10         True       Yes  NaN
# Canada     12        False       Yes  NaN

# %%
# Setting multi-level indexes

# Index data by country & pop
data_ind = data.set_index(['Country', 'pop'])
print(data_ind)

# List of tuples: canada, 0 & Pakistan, 0
rows_to_keep = [('Canada', 0), ('France', 10)]
print(rows_to_keep)

# Subset for rows to keep
print(data_ind.loc[rows_to_keep])
# Out:
#                cpc  drive_right Purchased
# Country  pop
# France   10.0   44         True        No
# Spain    20.0   27        False       Yes
# Germany  30.0   30         True        No
# Spain    20.0   38        False        No
# Germany  30.0   40         True       Yes
# France   10.0   35        False       Yes
# China    80.0   52         True        No
# India    60.0   48         True       Yes
# America  40.0   45         True        No
# Canada   NaN    12        False       Yes
# Pakistan NaN    10         True       Yes
# [('Canada', 0), ('France', 10)]
#               cpc  drive_right Purchased
# Country pop
# Canada  NaN    12        False       Yes
# France  10.0   44         True        No
#         10.0   35        False       Yes

# %%
# Sort data_ind by index values
print(data_ind.sort_index())

# Sort data_ind by index values at the city level
print(data_ind.sort_index(level='pop'))

# Sort data_ind by country then descending pop
print(data_ind.sort_index(level='Country', ascending=True))
# Out:
#                cpc  drive_right Purchased
# Country  pop
# America  40.0   45         True        No
# Canada   NaN    12        False       Yes
# China    80.0   52         True        No
# France   10.0   44         True        No
#          10.0   35        False       Yes
# Germany  30.0   30         True        No
#          30.0   40         True       Yes
# India    60.0   48         True       Yes
# Pakistan NaN    10         True       Yes
# Spain    20.0   27        False       Yes
#          20.0   38        False        No
#                cpc  drive_right Purchased
# Country  pop
# Canada   NaN    12        False       Yes
# Pakistan NaN    10         True       Yes
# France   10.0   44         True        No
#          10.0   35        False       Yes
# Spain    20.0   27        False       Yes
#          20.0   38        False        No
# Germany  30.0   30         True        No
#          30.0   40         True       Yes
# America  40.0   45         True        No
# India    60.0   48         True       Yes
# China    80.0   52         True        No
#                cpc  drive_right Purchased
# Country  pop
# America  40.0   45         True        No
# Canada   NaN    12        False       Yes
# China    80.0   52         True        No
# France   10.0   44         True        No
#          10.0   35        False       Yes
# Germany  30.0   30         True        No
#          30.0   40         True       Yes
# India    60.0   48         True       Yes
# Pakistan NaN    10         True       Yes
# Spain    20.0   27        False       Yes
#          20.0   38        False        No

# %%
data_ind = data.set_index(['Country', 'drive_right'])

#set level to drive_right (ascending) and then country(descending)

# %%
print(data_ind.sort_index(level=['drive_right','Country'], ascending=[True,False]))
# Out:
#                       cpc Purchased   pop
# Country  drive_right
# Spain    False         27       Yes  20.0
#          False         38        No  20.0
# France   False         35       Yes  10.0
# Canada   False         12       Yes   NaN
# Pakistan True          10       Yes   NaN
# India    True          48       Yes  60.0
# Germany  True          30        No  30.0
#          True          40       Yes  30.0
# France   True          44        No  10.0
# China    True          52        No  80.0
# America  True          45        No  40.0

# %%
# Sort the index of data_ind
data_srt = data_ind.sort_index()
print(data_srt)
# Subset rows from Pakistan to Russia
print(data_srt.loc['America':'Canada'])
# Out:
#                       cpc Purchased   pop
# Country  drive_right
# America  True          45        No  40.0
# Canada   False         12       Yes   NaN
# China    True          52        No  80.0
# France   False         35       Yes  10.0
#          True          44        No  10.0
# Germany  True          30        No  30.0
#          True          40       Yes  30.0
# India    True          48       Yes  60.0
# Pakistan True          10       Yes   NaN
# Spain    False         27       Yes  20.0
#          False         38        No  20.0
#                      cpc Purchased   pop
# Country drive_right
# America True          45        No  40.0
# Canada  False         12       Yes   NaN

# %%
# Use slicing in both directions at once
print(data)
print(data.iloc[0:6,2:5])
# Out:
#      Country  cpc  drive_right Purchased   pop
# 0     France   44         True        No  10.0
# 1      Spain   27        False       Yes  20.0
# 2    Germany   30         True        No  30.0
# 3      Spain   38        False        No  20.0
# 4    Germany   40         True       Yes  30.0
# 5     France   35        False       Yes  10.0
# 6      China   52         True        No  80.0
# 7      India   48         True       Yes  60.0
# 8    America   45         True        No  40.0
# 9     Canada   12        False       Yes   NaN
# 10  Pakistan   10         True       Yes   NaN
#    drive_right Purchased   pop
# 0         True        No  10.0
# 1        False       Yes  20.0
# 2         True        No  30.0
# 3        False        No  20.0
# 4         True       Yes  30.0
# 5        False       Yes  10.0

# %%
# Pivot avg_temp_c by country and city vs year
data_by_country_city_vs_year = data.pivot_table("cpc", index = ["Country", "pop"], columns = "Purchased")

# See the result
print(data_by_country_city_vs_year)
# Out:
# Purchased       No   Yes
# Country pop
# America 40.0  45.0   NaN
# China   80.0  52.0   NaN
# France  10.0  44.0  35.0
# Germany 30.0  30.0  40.0
# India   60.0   NaN  48.0
# Spain   20.0  38.0  27.0

# %%
#Chapter-1: Data Manipulation with pandas

# topic 1.4

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
data = pd.read_csv('Data2.csv')

# Print the head of the Data1
print(data.head())
# Out:
#    Country  cpc  drive_right Purchased   pop
# 0   France   44         True        No  10.0
# 1    Spain   27        False       Yes  20.0
# 2  Germany   30         True        No  30.0
# 3    Spain   38        False        No  20.0
# 4  Germany   40         True       Yes  30.0

# %%
# kind plot like line and bar etc
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Look at the first few rows of data
print(data.head())

# Get the total number of each size of pop
pop_size = data.groupby('Country')['pop'].sum()
print(pop_size)
# Create a bar plot of the number of data by size of pop
pop_size.plot(kind="line")

# Show the plot
plt.show()
# Out:
#    Country  cpc  drive_right Purchased   pop
# 0   France   44         True        No  10.0
# 1    Spain   27        False       Yes  20.0
# 2  Germany   30         True        No  30.0
# 3    Spain   38        False        No  20.0
# 4  Germany   40         True       Yes  30.0
# Country
# America     40.0
# Canada       0.0
# China       80.0
# France      20.0
# Germany     60.0
# India       60.0
# Pakistan     0.0
# Spain       40.0
# Name: pop, dtype: float64

# %%
# Scatter plot of nb_sold vs avg_price with title
data_tail=data.tail()
print(data_tail)
data_tail.plot(x='pop', y='Country', kind='scatter', title='countries vs. pop')
# Show the plot
plt.show()
# Out:
#      Country  cpc  drive_right Purchased   pop
# 6      China   52         True        No  80.0
# 7      India   48         True       Yes  60.0
# 8    America   45         True        No  40.0
# 9     Canada   12        False       Yes   NaN
# 10  Pakistan   10         True       Yes   NaN

# %%
# Histogram of conventional avg_price 
data[data["Country"] == "America"]["cpc"].hist()

# Histogram of organic avg_price
data[data["Country"] == "China"]["cpc"].hist()

# Add a legend
plt.legend(["Spain", "China"])

# Show the plot
plt.show()

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Check individual values for missing values
print(data.isna())

# Check each column for missing values
print(data.isna().any())

# Bar plot of missing values by variable
data.isna().sum().plot(kind='bar')

# Show plot
plt.show()
# Out:
#     Country    cpc  drive_right  Purchased    pop
# 0     False  False        False      False  False
# 1     False  False        False      False  False
# 2     False  False        False      False  False
# 3     False  False        False      False  False
# 4     False  False        False      False  False
# 5     False  False        False      False  False
# 6     False  False        False      False  False
# 7     False  False        False      False  False
# 8     False  False        False      False  False
# 9     False  False        False      False   True
# 10    False  False        False      False   True
# Country        False
# cpc            False
# drive_right    False
# Purchased      False
# pop             True
# dtype: bool

# %%
# Remove rows with missing values
data_complete = data.dropna()

# Check if any columns contain missing values
print(data_complete.isna().any())
# Out:
# Country        False
# cpc            False
# drive_right    False
# Purchased      False
# pop            False
# dtype: bool

# %%
data_complete
# Out:
#    Country  cpc  drive_right Purchased   pop
# 0   France   44         True        No  10.0
# 1    Spain   27        False       Yes  20.0
# 2  Germany   30         True        No  30.0
# 3    Spain   38        False        No  20.0
# 4  Germany   40         True       Yes  30.0
# 5   France   35        False       Yes  10.0
# 6    China   52         True        No  80.0
# 7    India   48         True       Yes  60.0
# 8  America   45         True        No  40.0

# %%
# List the columns with missing values
cols_with_missing = ["pop"]
#data_new=data.groupby('Country')
# Create histograms showing the distributions cols_with_missing
data[cols_with_missing].hist(bins=10)

# Show the plot
plt.show()

# %%
1. 10-80=70 #max - min
2. 70/5= 14 #result / bins
3. 10-24, #grouping

# %%
# Create a list of dictionaries with new data
avocados_list = [
    {'date': "2019-11-03", 'small_sold': 10376832, 'large_sold': 7835071},
    {'date': "2019-11-10", 'small_sold': 10717154, 'large_sold': 8561348},
]

# Convert list into DataFrame
avocados_2019 = pd.DataFrame(avocados_list)

# Print the new DataFrame
print(avocados_2019)
# Out:
#          date  small_sold  large_sold
# 0  2019-11-03    10376832     7835071
# 1  2019-11-10    10717154     8561348

# %%
# Create a dictionary of lists with new data
avocados_dict = {
  "date": ["2019-11-17", "2019-12-01"],
  "small_sold": [10859987, 9291631],
  "large_sold": [7674135, 6238096]
}

# Convert dictionary into DataFrame
avocados_2019 = pd.DataFrame(avocados_dict)

# Print the new DataFrame
print(avocados_2019)
# Out:
#          date  small_sold  large_sold
# 0  2019-11-17    10859987     7674135
# 1  2019-12-01     9291631     6238096

# %%
type(avocados_2019)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create avocado_sorted
avocados_2019_sorted = avocados_2019.sort_values('large_sold', ascending=False)

# Print airline_totals_sorted
print(avocados_2019_sorted)

# Save as airline_totals_sorted.csv
avocados_2019.to_csv('avocados_2019_sorted.csv')
# Out:
#          date  small_sold  large_sold
# 1  2019-11-10    10717154     8561348
# 0  2019-11-03    10376832     7835071
